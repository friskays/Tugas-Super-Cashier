# %%
import tugas_supercashier as sc
# Out:
# Selamat datang di program super cashier!
# Masukkan ID transaksi Anda: 1
# Silakan pilih menu:
# 1. Tambah item
# 2. Update nama item
# 3. Update jumlah item
# 4. Update harga item
# 5. Delete item
# 6. Reset Transaction
# 7. Cek Order
# 8. Hitung total
# 9. Keluar
# Masukkan pilihan Anda: 1
# Masukkan nama item: Ayam Goreng
# Masukkan jumlah item: 2
# Masukkan harga item: 20000
# +-------------+---------------+---------+------------+
# | Nama Item   |   Jumlah Item |   Harga |   Subtotal |
# +=============+===============+=========+============+
# | Ayam Goreng |             2 |   20000 |      40000 |
# +-------------+---------------+---------+------------+
# Tambah item lagi? (Y/N): y
# Masukkan nama item: Pasta Gigi
# Masukkan jumlah item: 3
# Masukkan harga item: 15000
# +-------------+---------------+---------+------------+
# | Nama Item   |   Jumlah Item |   Harga |   Subtotal |
# +=============+===============+=========+============+
# ...
